# %%
import pandas as pd
import docx # install python-docx
import glob

# %%
# See options here: https://stackoverflow.com/questions/25228106/how-to-extract-text-from-an-existing-docx-file-using-python-docx

def get_text(filename):
    
    with open(filename, "r") as f:
        text = f.read()
        
    return [el.strip() for el in text.strip().split("\n") if el.strip()]

# %%
word_files = glob.glob("data_files/scrubbed/*")
word_files
# Out:
# ['data_files/scrubbed/Camilla.txt',
#  'data_files/scrubbed/Mary_-_Wollstonecraft.txt',
#  'data_files/scrubbed/Millenium_Hall.txt',
#  'data_files/scrubbed/Euphemia_-_Lennox.txt',
#  'data_files/scrubbed/Blue_Jar_-_Edgeworth.txt',
#  'data_files/scrubbed/Mansfield_Park.txt',
#  'data_files/scrubbed/Sense&Sensibility.txt',
#  'data_files/scrubbed/Charlotte_Temple.txt',
#  'data_files/scrubbed/Blazing_World.txt',
#  'data_files/scrubbed/David_Simple.txt',
#  'data_files/scrubbed/Persuasion.txt',
#  'data_files/scrubbed/Emma.txt',
#  'data_files/scrubbed/Lady_Susan.txt',
#  'data_files/scrubbed/P&P.txt',
#  'data_files/scrubbed/The_Governess_-_Fielding.txt',
#  'data_files/scrubbed/Hermione_-_Lennox.txt',
#  'data_files/scrubbed/Evelina.txt',
#  'data_files/scrubbed/Basket_Woman_-_Edgeworth.txt',
#  'data_files/scrubbed/NorthangerAbbey.txt',
#  'data_files/scrubbed/Cecilia.txt',
#  'data_files/scrubbed/Wanderer.txt']

# %%
word_text = []

for file in word_files:
    word_text.append(
        {
            "title": file.split("/")[-1][:-5],
            "text": get_text(file)
        }
    )

# %%
word_text[0]
# Out:
# {'title': 'Camill',
#  'text': ['goodness inspires confidence divesting respect',
#   'terror excites attachment greatness presentation little',
#   'work majesty truly humbly evince',
#   'public manifestation duty regard obscure individual',
#   'betray ambition trust sure',
#   'natural majesty known exaltation rank',
#   'raise surprise scenes characters incidents',
#   'reference common life brought',
#   'presence inhabitant retired cottage',
#   'receives benign permission majesty feet casts',
#   'humble offering bears mind recollections live',
#   'memory holds seat benevolence withheld condition',
#   'delighting ways speed progress morality',
#   'channel flow port steer blush',
#   'inference leave open annexing undue importance',
#   'production apparently light kind',
#   'view fallacious eventually prove extended',
#   'whiling away idle hour dare seek patronage',
#   'deepest gratitude heartfelt respect',
#   'historian human life finds difficulty intricacy',
#   'develop accidents adventures investigator',
#   'human heart feelings changes vain fortune wave',
#   'coloured banner alternately regaling dismaying hues',
#   'glowing creation felicities tints',
#   'appear stained ingredients unmixed horrors rapid',
#   'vicissitudes unassimilating eccentricities mocked',
#   'laughed distanced wilder wonders heart',
#   'amazing assemblage possible contrarieties',
#   'steady perverseness spirit grafts',
#   'denied qualities indefinable resources',
#   'unfathomable weaknesses indefensible neighbours',
#   'judge dare trust lose ere learn',
#   'appreciate ere comprehend born',
#   'capacity leaps limit futility',
#   'absurdity lives surprise ceases beat void',
#   'inscrutable grand general view display',
#   'portrait fairly faintly delineate features',
#   'sole discriminate province pen trace nature',
#   'blot personality',
#   'repose welcome worn aged sick',
#   'unhappy danger difficulty toil',
#   'adventurous danger encounter forerunner success',
#   'difficulty spur ingenuity toil herald honour',
#   'experience teaches lesson truth blessings',
#   'tranquillity comes shape warning wisdom',
#   'turn aside defying disbelieving tis bitterness',
#   'personal proof suffering feeling erring',
#   'repenting experience comes conviction impresses',
#   'use',
#   'bosom respectable family resided nature',
#   'bounty profuse lavish attractions fortune',
#   'moderation kinder placed luxury',
#   'indigence abode parsonage house',
#   'beautifully situated unequal county',
#   'vicinity varied landscapes father',
#   'rector younger house living',
#   'considerable enabled incumbent attain rational object',
#   'modest circumscribed wishes bestow deserving wife',
#   'forbearance declined educate lovely race',
#   'daughters expansive propriety',
#   'unites improvement future present enjoyment',
#   'goodness heart principles piety exemplary couple',
#   'bound perfect unison character',
#   'tempers contrast scarce gradation',
#   'single shade smooth abrupt dissimilitude',
#   'gentle wisdom benign virtue saw compassion',
#   'imperfections doubled severity',
#   'spared mildness urged pity blinded',
#   'approve equity unerring judgment',
#   'indulgent partner firmness mind shake',
#   'calamity resolute prosperity powerless lull',
#   'duties asleep exalted character husband pride',
#   'existence source happiness merely',
#   'standard excellence endurance sense worth',
#   'criterion opinion instigated',
#   'spirit comparison uncandid',
#   'rarely escape proving injurious',
#   'unskillfulness fallible nature principle',
#   'impels right misleads deviations',
#   'ambition presumes point perfection instance',
#   'distinctness disposition stifled reciprocity',
#   'affection magnetic concentration marriage felicity',
#   'revered softened rigid virtues wife',
#   'adored fortified melting humanity husband',
#   'interchange happiness deserved parental',
#   'occupations promising passed married years',
#   'blest blessing pair event came pass extremely',
#   'interesting important consequences',
#   'receipt letter elder brother',
#   'containing meant remove',
#   'resided hereditary estate',
#   'family years older',
#   'seen marriage religious duties',
#   'domestic affairs having period detained benefice',
#   'passion field sports equal constancy kept',
#   'brother stationary',
#   'began letter kind enquiries welfare',
#   'family entered state',
#   'affairs briefly narrating lost health',
#   'knowing resolved change habitation',
#   'settle relations estate heard',
#   'sale desired brother',
#   'purchase hand prepare',
#   'unacquainted took granted',
#   'woman learning receive mere poor country squire',
#   'knew baby unborn begged',
#   'provide proper apartment niece',
#   'bring nephew',
#   'follow holidays forget',
#   'governess particular point pleasing',
#   'extremely gratified unexpected renewal fraternal',
#   'intercourse wrote warmest thanks brother executed',
#   'commission utmost alacrity mansion extensive',
#   'pleasure ground scarce distant parsonage house',
#   'bought fitted ready reception',
#   'course months impatient take possession',
#   'territory arrived speedily niece',
#   'welcomed gate park family',
#   'inherited ancestors unencumbered estate',
#   'annum enjoyed ease affluence',
#   'disseminated generous appeared',
#   'personal prosperity surrounded bestowed',
#   'shared common general right',
#   'dispensing bounty temper unalterably sweet',
#   'breast laid open world',
#   'infantine artlessness talents bore proportion',
#   'goodness heart insuperable want quickness',
#   'application early days having period',
#   'wholly uncultivated singularly self formed',
#   'dearth sedentary resources youth passed away',
#   'constant reproach health failed meridian',
#   'life consequences wound side occasioned fall',
#   'horse exercise active diversions',
#   'necessity relinquished hitherto occupied time',
#   'portion delighted devote hospitality',
#   'neighbourly offices equally strength',
#   'deprived employment destitute comfort',
#   'plan occur solace misfortunes',
#   'accidentally read newspapers estate',
#   'sale',
#   'niece accompanied beautiful little girl',
#   'orphan daughter deceased sister death parents',
#   'brother guardianship',
#   'charge small estate scarce',
#   'year sum fortune daughter',
#   'meeting source tender pleasure gave',
#   'birth family eager naturally',
#   'attached happiest early prejudices sight',
#   'relations received complacency due',
#   'brother husband higher',
#   'estimation fraternal comparison unavoidable disadvantage',
#   'insensible fair future',
#   'prospects children probable result',
#   'change abode',
#   'notwithstanding affections opened',
#   'sight claimants kindness dejected',
#   'person group',
#   'nature envy severe self upbraiding',
#   'followed view happiness brother regretted',
#   'married age owned fine family',
#   'repined unfortunate privileges birthright',
#   'indulging youth covet',
#   'drove attention modest foresight prepares',
#   'years consolation sure require',
#   'degrees satisfaction spread place',
#   'breast acknowledged sensibly revived',
#   'endearing reception candidly avowed',
#   'loss',
#   'journey having proper',
#   'proficiency youth filling time quite',
#   'behindhand',
#   'caressed children fondness struck',
#   'beauty nieces particularly',
#   'second daughter pretty',
#   'little sister sister',
#   'half beauty little',
#   'catching',
#   'little mouth quite wins',
#   'looks half laughing',
#   'suppose knows books',
#   'studying uncle little god knows',
#   'took proper sorry',
#   'coming discretion',
#   'addressing boy exhorted work hard',
#   'youth sundry anecdotes industry merit',
#   'father age quite',
#   'misfortune brought',
#   'continued present ignoramus',
#   'happened forefathers pleased keep',
#   'sharper look education',
#   'little boy casting comic glance begged',
#   'uncle meant sharper look',
#   'mean dear correction sure',
#   'done stood',
#   'neighbours',
#   'pray uncle pursing mouth hide',
#   'laughter thoughts',
#   'dear pretend age',
#   'taste proper',
#   'warning',
#   'hear rising generation',
#   'greater pitch time',
#   'advise friend guard',
#   'cousin coming eton school',
#   'christmas holidays turn mirror',
#   'scholarship given directions study night',
#   'day taken eating sleeping',
#   'continued having proved bad knowing',
#   'case right intermeddle',
#   'thank classics',
#   'dear little boy light',
#   'expect',
#   'house examined fair little took possession',
#   'apartment satisfied attention',
#   'paid rejoiced find room',
#   'window skylight means studies',
#   'observed receive interruption gaping staring',
#   'night advanced happiness',
#   'leaving prospect recovering spirits',
#   'revival lasted novelty scene',
#   'depression returned feelings health happier lot',
#   'brother born filled incessent',
#   'repentance mismanagement',
#   'measure atone resolved collect',
#   'family house dawning archness',
#   'expression instinctively caught demanded',
#   'parents reside',
#   'certainly little looks full',
#   'amusement',
#   'objected reposing trust',
#   'value appreciated secret fondest',
#   'mother rigour justice scarce permitted',
#   'partiality beat breast happy little',
#   'person need avowed distinction tide youthful glee flowed',
#   'jocund heart transparency fine blue veins',
#   'shewed velocity current look smile',
#   'step feeling',
#   'early felicity mind allay blissful state',
#   'innocence purity delight fleet fast scarcely',
#   'retrospection happiness known',
#   'tenderest hopes encircled object saw',
#   'proposal fairer light bore brother',
#   'certain residence secure ample fortune',
#   'governess entrusted take care little',
#   'girl removed hourly instructions',
#   'reach general super intendance mother',
#   'power cast uncontrolled reclaim started',
#   'occasion children provision ascertained life',
#   'short fulfill personal schemes economy',
#   'favour argument incontrovertible',
#   'silent begged reflect persuasive',
#   'attractions elegance refinement parental expectations',
#   'essentially disappointed moral lessons',
#   'practically inculcated uniform view goodness heart',
#   'firmness principle brother possessed eminent degree',
#   'character daughter',
#   'derive benefit undoubtedly point',
#   'receive injury',
#   'yielded resisted remonstrance',
#   'husband sense duty impelled murmur',
#   'retired room conceal complied',
#   'united despised',
#   'obeyed scrupulously happily',
#   'obeyed honoured partner considered vow taken altar',
#   'husband voluntary vestal held taken',
#   'maker dissent opinion exculpated mind',
#   'deviation',
#   'admiration adoring fixed character',
#   'submitted sure applaud motives swayed',
#   'little consequences met sentiments',
#   'contrariety wholly repugnant judgment genuine',
#   'warmth affection compliance',
#   'forbearance merely exempt pain',
#   'satisfaction sacrifice soothing heart',
#   'soul deeply affected excellencies',
#   'gratefully felt power religiously studied abuse',
#   'respected owed conscience tenderly returned',
#   'indebted affection render virtues conducive',
#   'happiness soften duties highest sense merit',
#   'sacred objects solicitude life',
#   'lively lovely little girl mingling tears separation',
#   'childish rapture novelty period',
#   'inspires preparing change remember',
#   'anxious mother devolves',
#   'sole charge unlimited judgment bring roof',
#   'appears danger having quitted',
#   'prompt thankful acceptance justice',
#   'sincerity offer cheerful acquiescence lessened',
#   'reluctance raised higher esteem constant mind',
#   'invariably looked summit chosen ambition',
#   'delighted acquisition household',
#   'revived dear brother sister family',
#   'visited proves fortunate step taken',
#   'born little jumps skips',
#   'eyes ache looking fear',
#   'breaking neck keep sharp watch poor',
#   'nose quite joint god forbid',
#   'life sorry dear brother',
#   'poor promises turn dull',
#   'sprightly little girl possessed heart guided',
#   'uncle refuse endearing entreaty',
#   'felt indulgence repaid enchantment gaiety',
#   'idol lost power please',
#   'essential kindness abated conduct acknowledged',
#   'beauty complete variety',
#   'captivation form mind equal elasticity',
#   'playful countenance rekindled spirits cheerfulness',
#   'animated voice awakened doted detaining',
#   'side delighted gratify wished absent',
#   'exhilarated pleasure supplied ideas',
#   'morning evening latest close eye followed',
#   'light springing figure ear vibrated sportive sounds',
#   'catching listened successive rotation spontaneous laugh',
#   'unconscious bound genuine glee childhood fearless',
#   'happiness uncurbed severity untamed misfortune',
#   'ascendance pointed servants',
#   'shewed resentment unexplained pouting sullenness',
#   'pass unnoticed unreflecting forgetfulness',
#   'mind empoisoned jealousy permanent',
#   'seriousness month residence',
#   'took resolution making heiress',
#   'notwithstanding fondness remonstrated',
#   'partiality injurious nephew niece',
#   'rest family secret heart',
#   'subscribed wonder predilection favour',
#   'maternally disturbed children felt justice',
#   'sensibly shocked blight unmerited hopes cherished',
#   'fruits change',
#   'plan reaped little darling robbed',
#   'sweetness mind correct undeserved bitterness',
#   'expectants',
#   'immoveable provide handsomely',
#   'settling pounds year',
#   'bequeath capital legacies rest',
#   'nephews nieces bulk fortune',
#   'amends having amused',
#   'gone prove loved',
#   'keep secret informed',
#   'riches destined inherit servants',
#   'respect attended took frequent opportunities impressing',
#   'expectation favours begged reversion',
#   'happy heiress heard little concern interest',
#   'ambition find room mind dance sing play',
#   'enliven rapture continued repetition requests',
#   'idea patronage familiar wholly uninfected',
#   'power consequence regaled',
#   'fancy presents friends designing',
#   'coach mamma oftener abroad horse',
#   'brother knew passionate wish',
#   'bureau lock key eldest sister innumerable',
#   'trinkets cousin dolls toys end',
#   'little sister library books finely bound',
#   'gilt papa munificent donations looked forward',
#   'anticipation womanhood hint surmised',
#   'surviving uncle impetuous shower tears damped',
#   'schemes deluged airy castle shewed instinctive',
#   'gratitude kindness awaken unthinking period',
#   'earliest youth bosoms power animate',
#   'ensuing birthday enter tenth year',
#   'adjoining country uncle splendid plan',
#   'favour brother sisters invited keep',
#   'declined asking father mother',
#   'time restraint dedicated promotion',
#   'festivity requested',
#   'appear day lest presence curb children spirits',
#   'little party consisting years older',
#   'years younger beautiful',
#   'cousin exactly age brother counted',
#   'years',
#   'assembled important occasion clock',
#   'morning breakfast',
#   'uncommonly spirited manly boy thirteen',
#   'years age heir finest estates county',
#   'bosom friend guardianship',
#   'consigned infancy superintended',
#   'care education zeal economy',
#   'placed tuition',
#   'consummate learning sent',
#   'twice year assiduously kept',
#   'studies personal instructions leave dear',
#   'friend father deathbed recommended',
#   'trust happy',
#   'daughter frequent intercourse',
#   'mistress affections oppose union',
#   'disparity fortune daughter',
#   'incomparable partner hardly fail counterbalance merit',
#   'avail declaration generous',
#   'forming plan bring connection bear felt',
#   'conscientiously absolved measures frustration',
#   'determined people grew promote impede',
#   'rising regard',
#   'estate beech park inherited',
#   'friendship late owner instinctively',
#   'transfused breast paid parental tenderness',
#   'watched cherished fondness veneration',
#   'truly filial',
#   'indulge delight little set brought forth',
#   'joyous meeting fruits sweetmeats cakes cards trinkets',
#   'blind fiddlers unlimited command mistress',
#   'ceremonies unbounded transports jovial',
#   'little group scarcely keep pace enjoyment sir',
#   'entered plays forgot pains',
#   'laughed laughed suffered darling little girl',
#   'govern direct pleasure whiskers cork',
#   'powdered brown covered thread paper black ribbon',
#   'queue metamorphosed female accoutering',
#   'fine cap enveloped small head',
#   'wig tying maid apron round waist rattle',
#   'hand doll lap baby',
#   'nurse amuse',
#   'excess merriment excited spread house',
#   'called servants comical sight',
#   'servants indulged numerous guests peep',
#   'windows resolved object performed',
#   'assigned joined hearty laughs grotesque',
#   'figure cordially encouraged proceedings',
#   'assuring diverted fall',
#   'horse advising zeal',
#   'dears younger',
#   'live matter',
#   'older point difference',
#   'grew weary stretching full length',
#   'prodigious yawn heigh ho dear take',
#   'away poor doll fear slip',
#   'little gigglers convulsions laughter entreated',
#   'nurse time longer frankly dears',
#   'play fain tired death',
#   'really pity airing',
#   'rest little sides stay play',
#   'fevers',
#   'trouble little souls advice today',
#   'days year teazing',
#   'instantly decided airing dissentient',
#   'voice entirely extreme humour won',
#   'hearts little party felt',
#   'entertainment depended presence carriage',
#   'ordered nieces',
#   'request gratified horses',
#   'desired fix route hesitated',
#   'variety choice proposed take',
#   'view house park gardens',
#   'referred matter exquisite',
#   'beauty juvenile admiration paid early obeisance',
#   'approved little heroine day assented pleasure',
#   'immediately set happy expedition',
#   'boys came offerings wild honeysuckle',
#   'sweetbriar grateful nosegays diffusing nature coach',
#   'windows carefully presenting fragrant',
#   'sympathising declared sisters',
#   'mere frights comparison fair cousin partiality',
#   'struggled vainly',
#   'trivial particular gave preference',
#   'ordered garden chair follow',
#   'park take side',
#   'grounds fatigue rest walk',
#   'received homage beaus pointed',
#   'beautiful prospects gathered fairest flowers',
#   'loaded ripest fruits',
#   'sooner observed hastily stopping',
#   'chair called aloud holloa hither boys',
#   'bring',
#   'bunch grapes',
#   'promised',
#   'ho give right',
#   'choice dear',
#   'place',
#   'uncle saw place liked',
#   'life',
#   'sure care',
#   'look tired',
#   'gravely paused speeches regarded turn',
#   'steadiness settling future destinies',
#   'unable keep single presently burst forth',
#   'aloud mental arrangement saying dears',
#   'quite taken fancy private',
#   'doubt estate',
#   'neighbourhood suitable',
#   'mean provided bought odd',
#   'parks acres pretend',
#   'proper calculation joined',
#   'finest domain county',
#   'contrary dear right',
#   'choose beauty tis mere fancy',
#   'prettiest face saw',
#   'prettier mean point winningness',
#   'fear consent greater pleasure',
#   'having girls cousins live',
#   'overlook park park day',
#   'mode telescope',
#   'perfectly understanding blushed deeply forgetting',
#   'declared offered grapes conceiving',
#   'mistress fine place smiled approving',
#   'complacency rest occupied objects',
#   'listen speech',
#   'moved flying',
#   'uncle chair informed heard gardener',
#   'half mile fair',
#   'begged difficulty obliging',
#   'incapable hesitating',
#   'carriage horses boys ordered',
#   'regret beautiful plantations beech',
#   'park relinquished fair',
#   'hardly proceeded yards smiles',
#   'brightened face eldest daughter',
#   'suddenly overcast giving place look dismay',
#   'effect abruptly painful recollection',
#   'perceived enquired cause tears rolled fast',
#   'cheeks guilty sin',
#   'forgive',
#   'eagerly endeavoured console fondly',
#   'hand little sympathetically crying kissing',
#   'begging matter holding',
#   'finest peach stores saying',
#   'cry dear cry take little bit peach dare',
#   'bad',
#   'weeping penitent besought leave coach',
#   'explain opened',
#   'door hasten discovery',
#   'bank road side dear',
#   'sure uncle world help',
#   'disobeyed mamma mean',
#   'forgot commands charged',
#   'stir small pox',
#   'beech park poor little',
#   'fair',
#   'vex kindly kissing tears',
#   'cheeks stay play',
#   'uncle drive beech park rest',
#   'fair take',
#   'expedient flew coach charging boys',
#   'curiosity ridden bank side listened',
#   'passed comfort',
#   'speaking',
#   'kindly looked pretty',
#   'cousin means subscribe opinion',
#   'retract',
#   'jumping carriage threw arms neck',
#   'uncle whispered passed poor innocent',
#   'little dear considering',
#   'age',
#   'looking window done',
#   'harm quite natural mamma',
#   'woman sense won expect head',
#   'age mine coach dear',
#   'drive airing',
#   'extreme delicacy constitution hitherto',
#   'deterred innoculating',
#   'scrupulously kept miscellaneous intercourse',
#   'neighbourhood weakness infancy promising',
#   'change health strength meant give terrible',
#   'disease security allows perpetual',
#   'alarm immediately heats present',
#   'unused disobedience happy practising',
#   'entreated return immediately',
#   'complied premising expect',
#   'play party dinner',
#   'coachman received fresh orders',
#   'communicated boys protesting lose',
#   'fair overtake regardless',
#   'remonstrances spurs horse galloped',
#   'looking alarm exclaimed',
#   'going break bones case',
#   'boys horseback',
#   'terrified begged boon requested',
#   'servant directly ride',
#   'dear wish',
#   'rest staying ball',
#   'supper ready overturned',
#   'soul pick',
#   'offered ride persuade truant return',
#   'thank dear thank',
#   'boy point horsemanship ignorant',
#   'sculls',
#   'fractured midst galloping god',
#   'forbid',
#   'bring',
#   'coach uncle pray',
#   'agreed small pox',
#   'means light notion people',
#   'diseases continued',
#   'sure time comes moped',
#   'people modes making sick',
#   'accord',
#   'pitying uneasiness came',
#   'town called footman hark ride',
#   'keep sharp look small pox',
#   'fair held suburbs arrived straggling',
#   'booths coach instance stopped',
#   'earnestly solicited leave alight fair',
#   'offered esquire consented desired',
#   'party tried vainly',
#   'excuse assured raise spirits bid',
#   'apprehension stay amuse little',
#   'take care came harm',
#   'sooner gone little girl follow',
#   'compassionately kissing owned right',
#   'declared hard punished',
#   'people particularities concession served',
#   'tears flow faster unable bear sight',
#   'answer conscience vexing',
#   'promising liked cry',
#   'ordered coachman drive booth',
#   'toys sold',
#   'having footman bring trinkets coach alighted',
#   'suffering little girl fear',
#   'accompany entered booth take hit',
#   'fancy playthings',
#   'grief gave ecstasy little hands',
#   'scarcely sustain loaded skirt white frock',
#   'determining rest children equally happy',
#   'selecting presents little group ignorant',
#   'encounter advanced booth',
#   'hardly time exclaim oho caught innocent',
#   'voice calling little boy matter',
#   'face little boy attention perceived',
#   'child apparently recovering small pox',
#   'instant saw dreaded sight darted',
#   'forward seized arms defiance playthings',
#   'struggles carried coach',
#   'agony terror little boy crying away',
#   'away dragged booth perfectly unconscious',
#   'covered head frock held fast',
#   'hands',
#   'aghast hurried booth scarce support',
#   'emotion leaned stick ejaculating',
#   'lord help poor creatures poor mortals',
#   'presence mind directly',
#   'carriage prevailed enter',
#   'perceived situation distress',
#   'affright driven saw sobbing child',
#   'held confined idea hiding',
#   'instantly sensible danger joining little sister',
#   'extremely perplexed afraid going sick',
#   'child infection coach sent',
#   'done',
#   'totally overset unexpected accident',
#   'conscience struck willful share risking utterly',
#   'helpless answer wished',
#   'give advice',
#   'called felt abilities short',
#   'life hitherto brought use begged return',
#   'immediately keep days',
#   'cousin undertook',
#   'assistance convey',
#   'seeing little sister',
#   'full contagion poor object disease',
#   'relieved sent word doubt',
#   'scholar age desired chaise',
#   'footman take charge horse',
#   'ordered coach',
#   'fulfilled injunctions alacrity',
#   'difficult task find painful appease',
#   'apprehensions advanced',
#   'sooth comfort ordered postilion',
#   'drive farmhouse forwarded boy',
#   'entreaties write lines',
#   'exculpation sorrowing daughter',
#   'complied little habit writing',
#   'sent messenger dine farmhouse',
#   'order give time compose epistle',
#   'early afternoon conveyed following letter',
#   'remarkable writer comparison brother',
#   'excuse deficiencies',
#   'apology beg angry little',
#   'business wanting right',
#   'mentioning excusable',
#   'light fault wisest having youths',
#   'learned subject wrong',
#   'ignorant speak properly',
#   'certainly caught small pox',
#   'lucky circumstance having',
#   'keep days sake infection',
#   'trust sense won fret',
#   'course nature',
#   'innoculated physician',
#   'fault meaning',
#   'offend comes dear sister won',
#   'take especially poor little tis hard',
#   'things happy time life',
#   'having done harm human soul poor dears tis',
#   'unhappy wicked god knows liable',
#   'proper beg brother',
#   'remain',
#   'justice brother mention master',
#   'behaviour done greatest honour',
#   'classics satisfaction person having',
#   'care education',
#   'rest day lost delights heiress',
#   'unfortunate adventure deprivation party',
#   'grounded fear blame greater',
#   'mortifications remained ball supper',
#   'remove lowered spirits',
#   'sufficiently depressing additional hardly',
#   'acknowledged weight mind relative small',
#   'pox',
#   'contrition trembling obtain',
#   'pardon deserved allowance',
#   'extreme want consideration anxiously waited time',
#   'call management person',
#   'considered childish children',
#   'precaution taken regard clothes',
#   'warding infection escaped',
#   'fixed day fetching little daughter sir',
#   'entreaty invited party',
#   'early morning amends',
#   'disappointment ball supper holiday',
#   'little sport previous arrival',
#   'voluntarily pledged word taken',
#   'abroad suffered appear strangers',
#   'various gambols enacted happy group',
#   'conducted security gaiety proposed',
#   'amusement riding plank park',
#   'plank immediately procured gardener placed',
#   'trunk old oak parted thick branches',
#   'boys eldest girls balanced turn',
#   'delight dexterity feared com little',
#   'grown anxious',
#   'repinings child demolished difficulty',
#   'indulge safety considerable',
#   'various experiments resolved trust',
#   'placing lap occupied end plank',
#   'desired rest necessary weight',
#   'equal seat',
#   'diversion short consequences',
#   'superintended balance poised',
#   'exactness sooner elevated',
#   'exceedingly giddy involuntarily loosened hold',
#   'fell arms ground',
#   'agitation fright stooped forward save lost',
#   'equilibrium rescuing followed',
#   'greatest confusion ensued admirable adroitness',
#   'preserved elder girls suffering accident',
#   'took care leaping instantly plank',
#   'extremely bruised pain concern',
#   'attention centered little incessant cries',
#   'raised apprehensions common mischief',
#   'carried house arms delivered',
#   'governess screamed time undressing',
#   'convinced received injury galloped unbid',
#   'surgeon horror hearing',
#   'pronounce shoulder knees',
#   'dislocated',
#   'agony remorse shut room power',
#   'issue command listen question prevailed',
#   'open door arrival',
#   'hastily rushing hurried meet snatching',
#   'hands pressing burst passionate',
#   'flood tears sobbed hate dear sister',
#   'help sorry believe',
#   'death poor hurt fly life',
#   'pale struck dread possessing presence mind',
#   'disengaged demanded find',
#   'rational answer',
#   'stairs purposing communicate tidings gently briefly stated',
#   'misfortune conducted poor little sufferer',
#   'nearly overpowered sight affecting',
#   'preserved faculties uses lamentation held',
#   'child arms necessary operations performing',
#   'surgeon bed watched side night',
#   'defiance precautions high fever came',
#   'grew worse',
#   'morning alarming state unfortunate',
#   'little innocent exhibited undoubted symptoms small pox',
#   'established share parental',
#   'task nursing afflicted child room',
#   'give consolation unhappy brother lived wholly',
#   'apartment refusing sight calling',
#   'monster wicked look',
#   'affectionate little girl pining exclusion continually presented',
#   'door',
#   'disease bore prognostic fatal consequences fond',
#   'parents lost redoubled attention',
#   'gave wholly despair darkened room',
#   'refused food bread water permitted approach',
#   'reviled invariably contrition willful murderer',
#   'state self punishment persevered distemper',
#   'unexpectedly took sudden happy turn surgeon known',
#   'patient possibly recover',
#   'frantic grief',
#   'hastened drawing room commanded house',
#   'illuminated promised year wages servants bid',
#   'housekeeper distribute beef broth village',
#   'sent directions bells nearest parish churches',
#   'rung day night avert',
#   'horror wholly unprepared disappointment represented',
#   'precarious state changes feared',
#   'desperately reversed orders returned sadly dark room',
#   'protested rejoice',
#   'news',
#   'anxiously waited length arrived seamed',
#   'scarred horrible disorder declared danger',
#   'burying anguish alteration',
#   'safety child heart overflowing pious gratitude',
#   'messenger peace holding hand',
#   'assured little',
#   'ecstasy power check forgot pain',
#   'infirmity hurry apartment little girl',
#   'kneel feet give thanks',
#   'recovery entered room saw dreadful havoc',
#   'grim disease face trace beauty',
#   'resemblance known shrunk wrung',
#   'hands called sinful created beings',
#   'deepest despondence sunk chair wept aloud',
#   'began cry unconscious cause',
#   'remonstrated uselessness',
#   'transports calmly beseeching retire compose',
#   'sister away sure',
#   'want look doing',
#   'brother sister kill return amends',
#   'amends poor little trifle money',
#   'god knows worth',
#   'gone ay single shilling die',
#   'tomorrow',
#   'starting revived courage idea ventured',
#   'turn head exclaiming',
#   'ease poor conscience making murderer',
#   'guinea pit poor face settle',
#   'hand breathe fear dying',
#   'mean time',
#   'scarce noticed declaration brother endeavoured',
#   'dissuade sudden partial measure',
#   'listen speed stairs called hastily',
#   'hat stick commanded servants attend',
#   'muttering frequent ejaculations trust',
#   'changing mind proceeded family chapel approaching',
#   'eager steps altar knelt bidding hear',
#   'witness solemn vow',
#   'cleared crime murder recovery',
#   'atone done bequeathing',
#   'possessed world estate cash property',
#   'deduction sixpence',
#   'present remember witness case apoplexy',
#   'written',
#   'returning house lightened load',
#   'self reproach rendered fortnight insupportable',
#   'sent attorney neighbouring town upstairs',
#   'firmer mind wait arrival sick room',
#   'dear uncle banished hearing',
#   'stairs skipped lightly glad',
#   'ended acquired tranquility',
#   'satisfaction forsook appearance little darling',
#   'considered innocent creature preparing injure',
#   'bear look heart smote favour',
#   'eyes filled tears unable slow',
#   'trembling steps moved room',
#   'dearest uncle holding coat hanging',
#   'arm won speak',
#   'dear sure endeavouring hide',
#   'emotion follow going',
#   'remarkably busy',
#   'uncle plaintively seen',
#   'wished unhappy',
#   'locked door rap hard',
#   'fear asleep',
#   'uncle send away',
#   'dear increased agitation',
#   'worst enemy reason',
#   'care away beg bad',
#   'give thanks little playful gambols',
#   'having offer poor return',
#   'uncle niece',
#   'shut room leaving drowned tears',
#   'outside door',
#   'wretched reflecting shock disappointment',
#   'disposition affairs occasion fortitude',
#   'inform intention desired speak',
#   'family resided present',
#   'abruptly destination vowed',
#   'wealth beseeching break softest manner',
#   'poor little favourite assuring',
#   'point mere conscience forced choice',
#   'heiress',
#   'zeal serve oblige severe',
#   'test hesitated obey injunction refuse',
#   'servants house enabled',
#   'pleased anticipate incautiously news followed',
#   'garden wandered weep unobserved',
#   'stopped short sight distress conceiving errand',
#   'known determined consult',
#   'communicated terrible embassy entreating devise',
#   'consolation poor cousin',
#   'felt chagrined transaction',
#   'give attention murmured scruple',
#   'deprivation expected',
#   'time brother expressed resentment behaviour',
#   'uncle mingled repining merely',
#   'late preference recovery little',
#   'heard surprise wondered find',
#   'beauty attracted failure nature',
#   'pursued weeping dispersing tears',
#   'approach pretended picking lavender keeping eyes',
#   'steadfastly bush took',
#   'sprig spoke voice involuntary compassion',
#   'lost self command big drops rolled fast',
#   'cheeks extremely concerned strove gently sooth',
#   'expressions regret uncle avoidance escaped',
#   'convinced task performed anxious',
#   'fear consequences blow unlooked executed',
#   'speed consideration power',
#   'understood passionately clasped hands',
#   'exclaimed uncle loves',
#   'sure wicked envy',
#   'poor little suffered dying',
#   'richer',
#   'delighted relieved grown times',
#   'beautiful eagerly hand',
#   'apartment poor disconsolate eyes',
#   'overflowed tenderness admiration uncommon scene',
#   'witnessed generous affection consoled',
#   'fond distress uncle springing disappointment',
#   'loss',
#   'stayed arrival attorney took directions',
#   'immediate satisfaction short deed',
#   'making vow die possessed',
#   'qualification whatsoever niece',
#   'properly signed sealed hastened stairs',
#   'copy',
#   'remonstrance ineffectual conscience protested',
#   'appeased little forgiven',
#   'usage bear look change worse',
#   'finding heartstrings ready burst sight',
#   'brother suffered',
#   'conscience little ease',
#   'died comfort twas',
#   'murdered given satisfaction having',
#   'hand poor having',
#   'head thank heaven need care',
#   'matter mere loss beauty pretty',
#   'look injury splendid',
#   'fortune certainly point lasting',
#   'beauty lord help eye',
#   'walked child intending kiss stopped',
#   'sighed involuntarily looked saying',
#   'live believe',
#   'sure true',
#   'change poor little dear',
#   'doing innocently meaning god knows',
#   'time little girl recovered',
#   'misfortune daily palpable latent incurable',
#   'mischief owing fall grow leg shorter',
#   'figure diminutive deformed',
#   'additional evils reconciled parents partial',
#   'uncle wanting equity',
#   'reparation offered innocent sufferer ills',
#   'insurmountable',
#   'tumult affair subsided family',
#   'prepared reestablish',
#   'inducement separation take',
#   'disinherited pleasure sight',
#   'embittered regret remorse courage',
#   'smallest opposition spent day departure groans',
#   'penitence right detain',
#   'decided heiress brought',
#   'loss amusing society favourite disappointment',
#   'inflicted sweetness borne',
#   'preyed incessantly spirits knew employ',
#   'direct thoughts manner beguile',
#   'time children gone rest',
#   'view constant resources brother',
#   'literature augmented melancholy imperfections',
#   'steady industry early youth attained',
#   'devoted field sports observed',
#   'wonder pity looked self reproach',
#   'recognised effect reverence awful',
#   'imagination regulated wisdom disciplined',
#   'experience having taken turn fancied',
#   'earthly misfortune originated carelessness learning',
#   'wished wanted upbraided ignorance',
#   'disease pain afflicted lamented juvenile inattention',
#   'robbed acquirements taught',
#   'regard word scholar named presence heaved',
#   'deepest sigh article newspaper',
#   'unacquainted discussed reviled early heedlessness study',
#   'mention common pamphlet unknown gave',
#   'sensation disgrace inevitable calamities attributed',
#   'negligence education construed error evil',
#   'life youthful disrespect greek latin',
#   'state mind ordinary maladies',
#   'serious aggravation violent fit gout',
#   'midst acute anguish useless repentance',
#   'alternately ravaged happiness suddenly occurred',
#   'proper instruction obtain sufficient',
#   'portion enviable knowledge enable pass evenings',
#   'similarity brother',
#   'revived suggestion sent communicate',
#   'idea beg recover lost',
#   'time recommending tutor set',
#   'course studies want particular',
#   'figure scholar learn',
#   'amuse odd hours forget gout',
#   'total impossibility project answer given',
#   'purpose deterred listening request mild',
#   'philosophy character saw lenient human sufferings',
#   'eligible looked obstacles wishes',
#   'investigate gratification compatible',
#   'innocence wrote college associate',
#   'younger years knew severely embarrassed affairs',
#   'proposals settling house brother',
#   'merely gratefully accepted old friend forth',
#   'confession daily menaced public arrest debts',
#   ...]}

# %%
df = pd.DataFrame(word_text)

# %%
df.head()
# Out:
#                   title                                               text
# 0                Camill  [goodness inspires confidence divesting respec...
# 1  Mary_-_Wollstonecraf  [heroine fiction daughter, married gentle fash...
# 2         Millenium_Hal  [london promised write, reached northern retre...
# 3      Euphemia_-_Lenno  [greatest pleasures proposed return meet dear ...
# 4   Blue_Jar_-_Edgewort  [little girl years age walking, mother streets...

# %%
df_lines = df.explode("text")

# %%
df_lines
# Out:
#       title                                               text
# 0    Camill     goodness inspires confidence divesting respect
# 0    Camill  terror excites attachment greatness presentati...
# 0    Camill                   work majesty truly humbly evince
# 0    Camill  public manifestation duty regard obscure indiv...
# 0    Camill                         betray ambition trust sure
# ..      ...                                                ...
# 20  Wandere                                 virtue calumniated
# 20  Wandere                 difficulties insurmountable mental
# 20  Wandere                 courage operating principle supply
# 20  Wandere  physical force combat disappointment keep unta...
# 20  Wandere                            superiour failure alive
#
# [187683 rows x 2 columns]

# %%
df_lines["line_num"] = (df_lines.groupby("title").cumcount() + 1)

# %%
df_lines.head(20)
# Out:
#     title                                               text  line_num
# 0  Camill     goodness inspires confidence divesting respect         1
# 0  Camill  terror excites attachment greatness presentati...         2
# 0  Camill                   work majesty truly humbly evince         3
# 0  Camill  public manifestation duty regard obscure indiv...         4
# 0  Camill                         betray ambition trust sure         5
# 0  Camill              natural majesty known exaltation rank         6
# 0  Camill         raise surprise scenes characters incidents         7
# 0  Camill                      reference common life brought         8
# 0  Camill                presence inhabitant retired cottage         9
# 0  Camill      receives benign permission majesty feet casts        10
# 0  Camill      humble offering bears mind recollections live        11
# 0  Camill   memory holds seat benevolence withheld condition        12
# 0  Camill            delighting ways speed progress morality        13
# 0  Camill                      channel flow port steer blush        14
# 0  Camill     inference leave open annexing undue importance        15
# 0  Camill                   production apparently light kind        16
# 0  Camill          view fallacious eventually prove extended        17
# 0  Camill         whiling away idle hour dare seek patronage        18
# 0  Camill                deepest gratitude heartfelt respect        19
# 0  Camill    historian human life finds difficulty intricacy        20

# %%
df_lines.shape
# Out:
# (187683, 3)

# %%
df_lines.text.str.split().explode().str.strip().value_counts()[:50]
# Out:
# little      4071
# time        3952
# dear        2304
# mind        2187
# give        2140
# house       2075
# take        2060
# room        1944
# sir         1804
# heart       1782
# day         1764
# saw         1752
# life        1737
# world       1731
# lord        1665
# having      1624
# sure        1619
# quite       1602
# away        1600
# poor        1599
# friend      1589
# came        1588
# pleasure    1501
# look        1491
# mother      1488
# father      1460
# heard       1457
# eyes        1367
# place       1365
# wish        1359
# felt        1357
# woman       1345
# sister      1330
# knew        1326
# find        1308
# hand        1306
# believe     1303
# family      1297
# letter      1288
# manner      1284
# morning     1265
# old         1255
# present     1250
# leave       1246
# speak       1230
# person      1208
# gave        1207
# happy       1183
# hear        1178
# done        1178
# Name: text, dtype: int64
